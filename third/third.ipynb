# %%
text = """...""".replace(" ", "").replace("\n", "")



freq = dict()
symbols = list()
for symbol_index in range(0, len(text), 1):
    symbol = text[symbol_index:symbol_index + 1]
    symbols.append(symbol)
    freq[symbol] = freq.get(symbol, 0) + 1
print(symbols, end=" ")
# Out:
# ['9', '3', '8', '4', '9', '4', '7', '3', '8', '3', '0', '4', '3', '5', '4', '2', '5', '1', '6', '1', '3', '1', '5', '4', '2', '4', '5', '3', '1', '4', '0', '8', '4', '3', '0', '3', '3', '0', '9', '5', '4', '6', '5', '2', '2', '4', '2', '4', '8', '4', '6', '4', '0', '4', '3', '2', '4', '2', '3', '5', '3', '8', '4', '1', '3', '0', '5', '9', '3', '8', '4', '5', '3', '8', '4', '7', '2', '4', '2', '5', '3', '0', '2', '4', '6', '6', '1', '4', '7', '3', '8', '3', '5', '3', '8', '9', '6', '2', '1', '0', '6', '9', '4', '1', '3', '1', '5', '4', '5', '3', '8', '3', '4', '4', '0', '4', '7', '4', '7', '3', '8', '3', '0', '1', '6', '1', '3', '8', '3', '5', '6', '2', '1', '6', '1', '4', '8', '3', '0', '3', '5', '3', '8', '9', '4', '7', '2', '4', '6', '5', '3', '0', '6', '1', '3', '3', '4', '0', '3', '1', '4', '0', '4', '1', '4', '7', '2', '3', '3', '4', '0', '4', '7', '4', '3', '3', '8', '4', '8', '4', '1', '3', '8', '4', '8', '5', '6', '2', '0', '3', '3', '2', '1', '4', '0', '4', '6', '6', '1', '4', '7', '2', '3', '4', '5', '4', '8', '2', '3', '2', '4', '5', '3', '8', '3', '1', '3', '8', '4', '1', '4', '3', '4', '0', '2', '3', '8', '4', '7', '3', '3', '0', '1', '6', '1', '4', '7', '4', '0', '4', '8', '4', '2', '6', '2', '4', '6', '3', '0', '6', '2', '4', '2', '5', '4', '5', '3', '8', '4', '6', '3', '8', '4', '8', '0', '4', '3', '5', '4', '3', '2', '3', '2', '4', '5', '4', '6', '0', '3', '5', '3', '8', '3', '0', '1', '4', '0', '4', '4', '9', '3', '8', '4', '5', '4', '7', '5', '4', '8', '3', '8', '3', '1', '3', '8', '1', '2', '1', '6', '1', '4', '8', '4', '0', '4', '1', '6', '1', '4', '8', '6', '5', '4', '8', '4', '0', '4', '2', '8', '6', '5', '6', '2', '6', '0', '1', '0', '4', '0', '4', '8', '0', '4', '1', '3', '8', '9', '3', '8', '4', '4', '4', '8', '6', '5', '4', '8', '4', '0', '4', '2', '3', '8', '4', '7', '5', '8', '6', '5', '9', '4', '7', '4', '0', '1', '5', '9', '0', '3', '0', '1', '3', '1', '3', '8', '2', '4', '6', '5', '3', '5', '5', '3', '1', '3', '8', '3', '3', '4', '3', '0', '4', '3', '3', '8', '4', '7', '3', '4', '4', '0', '3', '1', '1', '3', '8', '4', '8', '2', '1', '3', '8', '4', '5', '4', '1', '5', '4', '2', '5', '4', '8', '6', '2', '4', '2', '6', '5', '4', '8', '5', '4', '4', '4', '5', '4', '6', '5', '4', '2', '5', '3', '8', '1', '3', '0', '1', '6', '5', '4', '1', '5', '2', '8', '4', '0', '4', '5', '2', '4', '7', '5', '4', '3', '3', '1', '5', '4', '4', '3', '0', '4', '8', '4', '0', '1', '5', '4', '7', '5', '3', '0', '9', '4', '0', '3', '6', '2', '4', '6', '8', '6', '5', '6', '2', '4', '5', '3', '8', '3', '1', '3', '8', '4', '1', '3', '8', '4', '3', '5', '4', '4', '4', '7', '5', '3', '0', '9', '4', '0', '3', '6', '2', '4', '6', '4', '1', '5', '3', '5', '3', '1', '2', '4', '0', '3', '2', '5', '4', '4', '1', '6', '5', '4', '1', '3', '8', '9', '3', '8', '4', '4', '4', '1', '0', '3', '1', '5', '4', '3', '1', '6', '5', '3', '9', '5', '3', '1', '3', '6', '2', '3', '1', '3', '8', '4', '8', '5', '4', '7', '4', '7', '6', '5', '4', '4', '4', '8', '3', '8', '4', '2', '6', '1', '9', '2', '1', '5', '4', '3', '0', '6', '9', '4', '9', '4', '0', '8', '0', '1', '6', '5', '4', '6', '3', '8', '3', '3', '4', '3', '0', '4', '8', '2', '4', '7', '3', '4', '5', '2', '4', '6', '2', '4', '6', '0', '3', '3', '3', '6', '4', '0', '4', '3', '3', '8', '4', '7', '6', '1', '6', '2', '4', '3', '0', '3', '2', '3', '8', '3', '1', '3', '8', '3', '6', '2', '3', '2', '4', '3', '3', '8', '4', '7', '3', '9', '4', '0', '1', '2', '2', '4', '1', '2', '4', '3', '0', '3', '3', '2', '1', '4', '0', '4', '6', '6', '1', '4', '7', '2', '3', '4', '4', '0', '3', '5', '3', '8', '4', '5', '3', '8', '4', '8', '3', '8', '3', '1', '2', '3', '8', '8', '3', '0', '1', '3', '8', '6', '2', '1', '4', '0', '4', '6', '6', '1', '4', '7', '3', '8', '1', '4', '0', '9', '8', '3', '8', '4', '6', '4', '0', '4', '0', '3', '8', '4', '7', '5', '1', '4', '0', '8', '6', '2', '4', '2', '4', '7', '5', '4', '0', '1', '3', '3', '1', '3', '8', '1', '6', '5', '4', '7', '4', '0', '1', '3', '1', '4', '0', '3', ...

# %%
symbols_ordered_by_freq = [(symbols, freq.get(symbols), i + 1) for i, symbols in enumerate(sorted(freq, key=freq.get, reverse=True))]
symbols_ordered_by_freq
# Out:
# [('4', 198, 1),
#  ('3', 161, 2),
#  ('8', 88, 3),
#  ('1', 81, 4),
#  ('5', 80, 5),
#  ('0', 74, 6),
#  ('6', 66, 7),
#  ('2', 65, 8),
#  ('7', 31, 9),
#  ('9', 21, 10)]

# %%
code = [
         ["7", "5", "3", "4", "1", "0", "2", "6", "9", "8"],
         ["З", "А", "И", "Р", ".", ".", ".", ".", ".", "."],
    ["4", "Б", "В", "Г", "Д", "Е", "Ж", "Й", "К", "Л", "М"],
    ["8", "Н", "О", "П", "С", "Т", "У", "Ф", "Х", "Ц", "Ч"],
    ["3", "Ш", "Щ", "Ь", "Ы", "Ь", "Э", "Ю", "Я", ".", "."],
]
MODE = "SPLIT" #"SPLIT"
splited_text = ""
symbol_index = 0
last_index = 0
while symbol_index < len(text):
    for code_row in range(2, len(code)):
        if text[symbol_index] in code[code_row]:
            tmp = text[symbol_index]
            symbol_index += 1
            splited_text += tmp + text[symbol_index] if MODE == "SPLIT" else code[code_row][code[0].index(text[symbol_index]) + 1]
            last_index = symbol_index
            break
    if last_index != symbol_index or symbol_index == 0:
        splited_text += " " + text[symbol_index] if MODE == "SPLIT" else code[1][code[0].index(text[symbol_index])]
        last_index = symbol_index
    symbol_index += 1
print("GOOD SPLIT" if len(text) - 1 == last_index else "BAD SPLIT")
print(splited_text, "\n")
# Out:
# GOOD SPLIT
#  9384947383043 542 5 1 6 131 542453140843033 0 9 546 5 2 24248464043 24235384130 5 938453847 242 530 246 6 147383538 9 6 2 1 0 6 94131 54538344047473830 1 6 13835 6 2 1 6 148303538 947 246 530 6 1334031404147 2334047433848413848 5 6 2 033 2 14046 6 147 234 548 23245383138414340 2384733 0 1 6 147404842 6 24630 6 242 54538463848 043 543 2324546 0353830 14044 9384547 548383138 1 2 1 6 1484041 6 148 6 548404286 5 6 2 6 0 1 04048 04138 9384448 6 54840423847 586 5 94740 1 5 9 030 13138 246 535 531383343 0433847344031 13848 2 1384541 542 548 6 242 6 548 5444546 542 538 130 1 6 541 5 284 045 247 54331 544304840 1 547 530 94036 24686 5 6 245383138413843 54447 530 94036 24641 53531 24032 544 1 6 54138 9384441 031 543 1 6 539 53136 2313848 54747 6 544483842 6 1 9 2 1 543 0 6 9494080 1 6 546383343 048 24734 5 246 246 0333640433847 6 1 6 243 03238313836 2324338473940 1 2 241 243 033 2 14046 6 147 2344035384538483831 23883 0 138 6 2 14046 6 14738 140 98384 640403847 5 14086 24247 540 133 138 1 6 54740 1314035 53343 543384447 28041 6 1474042 5804641 6 545 5 547 5323831383640 9303340 1 0

# %%
freq = dict()
bigrams = list()
for symbol_index in range(0, len(splited_text), 2):
    symbol = splited_text[symbol_index:symbol_index + 2]
    bigrams.append(symbol)
    freq[symbol] = freq.get(symbol, 0) + 1
print(bigrams, end=" ")
print("\nlen={}".format(len(bigrams)))
symbols_ordered_by_freq = [(bigramm, freq.get(bigramm), i + 1) for i, bigramm in enumerate(sorted(freq, key=freq.get, reverse=True))]
symbols_ordered_by_freq
# Out:
# [' 9', '38', '49', '47', '38', '30', '43', ' 5', '42', ' 5', ' 1', ' 6', ' 1', '31', ' 5', '42', '45', '31', '40', '84', '30', '33', ' 0', ' 9', ' 5', '46', ' 5', ' 2', ' 2', '42', '48', '46', '40', '43', ' 2', '42', '35', '38', '41', '30', ' 5', ' 9', '38', '45', '38', '47', ' 2', '42', ' 5', '30', ' 2', '46', ' 6', ' 1', '47', '38', '35', '38', ' 9', ' 6', ' 2', ' 1', ' 0', ' 6', ' 9', '41', '31', ' 5', '45', '38', '34', '40', '47', '47', '38', '30', ' 1', ' 6', ' 1', '38', '35', ' 6', ' 2', ' 1', ' 6', ' 1', '48', '30', '35', '38', ' 9', '47', ' 2', '46', ' 5', '30', ' 6', ' 1', '33', '40', '31', '40', '41', '47
# len=544
# [(' 5', 58, 1),
#  ('38', 54, 2),
#  (' 1', 46, 3),
#  (' 2', 44, 4),
#  (' 6', 38, 5),
#  ('40', 36, 6),
#  ('47', 31, 7),
#  ('48', 22, 8),
#  (' 0', 20, 9),
#  ('43', 19, 10),
#  ('31', 19, 11),
#  ('46', 18, 12),
#  (' 9', 17, 13),
#  ('41', 16, 14),
#  ('30', 15, 15),
#  ('42', 15, 16),
#  ('45', 13, 17),
#  ('33', 12, 18),
#  ('35', 9, 19),
#  ('44', 9, 20),
#  ('32', 6, 21),
#  ('36', 6, 22),
#  ('34', 5, 23),
#  ('86', 4, 24),
#  ('84', 3, 25),
#  ('80', 3, 26),
#  ('49', 2, 27),
#  ('39', 2, 28),
#  ('83', 2, 29)]

# %%
def print_replace(bigrams, dict_replace):
    for bi in bigrams:
        if bi in dict_replace:
            bi = dict_replace[bi]
        print(bi, end = '')

# %%
tt = [txt.lower().replace("—", "").replace("\"", "").replace(".", "").replace("-", "").replace("–", "").replace("!", "").replace("?", "").replace(",", "").replace("«", "").replace("»", "").replace("…", "").replace(":", "").strip().replace(" ", "") for txt in t.split("\n") if txt != ""]
t_txt = "".join(tt)
N = 45
find_str = bigrams[:35]
find_indexes = set()
for find_char in find_str:
    find_indexes.add(tuple(i for i, chr in enumerate(find_str) if chr == find_char))
print(find_indexes)
for i in range(len(t_txt) - N):
    #if len(i) > 6: #and i[0] == i[7]:       
        "оеаинтсрвлкмдпуяэыбгчйжьжёжшюцъщзф"
        p = t_txt[i:i+N]
        #                       12345678901234567890123456789012
        freq_russian_symbols = "оеатн..д.р.б...уь.....мхш......."#"оеаинтсрвлкмдпуяэыбгчйжьжёжшюцъщзф"
        dict_replace = {str(pair[0]) : freq_russian_symbols[index] for index, pair in enumerate(symbols_ordered_by_freq)}
        test_txt = ""
        for bi in bigrams:
            if bi in dict_replace:
                bi = dict_replace[bi];
            test_txt = test_txt + bi
            

        if len(p) < len(find_str):
            continue

        good = True
        for indexes in find_indexes:
            for index in range(1, len(indexes)):
                if p[indexes[index - 1]] != p[indexes[index]]:
                    good = False
        
        if( good ):
            print("-------------------------------------\n{}\n".format(p))
            print_replace(bigrams, dict_replace)
            print("\n***********************\n\n")       
            print([i[2] for i in symbols_ordered_by_freq if i[0] == bigrams[test_txt.find(".")]][0])
# Out:
# {(18, 32), (21,), (7, 9, 14, 24, 26), (27, 28, 34), (22,), (25, 31), (2,), (6, 33), (3,), (10, 12), (1, 4), (30,), (13, 17), (5, 20), (16,), (11,), (8, 15, 29), (19,), (0, 23)}

# %%
t = open('/Users/owl/Pycharm/PycharmProjects/KMZ/third/book.txt', 'r')
t = t.read()
